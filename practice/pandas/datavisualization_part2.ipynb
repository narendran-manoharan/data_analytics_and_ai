# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df = df.sample(frac=0.33, random_state=1)
df.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 234  Gentoo  Biscoe            45.8           14.6              210.0
# 294  Gentoo  Biscoe            46.4           15.0              216.0
# 301  Gentoo  Biscoe            52.5           15.6              221.0
# 51   Adelie  Biscoe            40.1           18.9              188.0
# 150  Adelie   Dream            36.0           17.1              187.0
#
#      body_mass_g     sex
# 234       4200.0  Female
# 294       4700.0  Female
# 301       5450.0    Male
# 51        4300.0    Male
# 150       3700.0  Female

# %%
df.plot(kind="scatter", y="bill_length_mm", x= "bill_depth_mm",  figsize= (10, 6))
plt.show()

# %%
df.plot(kind="scatter", y="bill_length_mm", x= "bill_depth_mm",  figsize= (10, 6), c="body_mass_g", colormap= "viridis")
plt.show()

# %%
df.plot(kind= "scatter",
        figsize= (10, 6),
        y= "bill_length_mm",
        x= "bill_depth_mm", 
        c= "bill_length_mm", 
        colormap= "plasma",
        s= df["body_mass_g"],
        alpha= 0.7
        )
plt.show()

# %%
df.plot(kind="scatter",
        figsize= (10, 6),
        x= "bill_length_mm",
        y= "bill_depth_mm",
        c= "body_mass_g", 
        s= df["body_mass_g"]/55,
        colormap= "viridis", 
        alpha = 0.7)
plt.show()

# %%
df= sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["time"].value_counts()
# Out:
# time
# Dinner    176
# Lunch      68
# Name: count, dtype: int64

# %%
df.plot(kind= "scatter", 
        y= "tip",
        x= "total_bill",
        c= df["total_bill"],
        s= df["size"]+ 20,
        colormap="viridis",
        alpha=0.7,
        figsize= (10,6)
        )
plt.show()

# %%
df.plot(
    kind="area",
    figsize= (10,6),
    y= ["tip", "total_bill"],
    x= "time",
    stacked=False
    )
plt.show()

# %%
df= sns.load_dataset("penguins")
df= df.sample(frac=0.5, random_state=1)
df.head()
# Out:
#     species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 306  Gentoo  Biscoe            43.4           14.4              218.0
# 341  Gentoo  Biscoe            50.4           15.7              222.0
# 291  Gentoo  Biscoe            46.4           15.6              221.0
# 102  Adelie  Biscoe            37.7           16.0              183.0
# 289  Gentoo  Biscoe            50.7           15.0              223.0
#
#      body_mass_g     sex
# 306       4600.0  Female
# 341       5750.0    Male
# 291       5000.0    Male
# 102       3075.0  Female
# 289       5550.0    Male

# %%
df["species"].value_counts()
# Out:
# species
# Adelie       75
# Gentoo       60
# Chinstrap    37
# Name: count, dtype: int64

# %%
df.value_counts(["species"]).plot(kind = "bar", figsize=(10, 6))
plt.xticks(rotation=0)
plt.show()

# %%
df.value_counts("island").plot(kind="barh", y="island", figsize=(10, 6))
plt.xticks(rotation=0)
plt.show()

# %%
for col in df.select_dtypes(include="object").columns:
    df.value_counts(col).plot(kind="barh", y= "col", figsize=(10,6)),
    print(f"* {col} barh plot")
    plt.show()
    print("\n\n")
# Out:
# * species barh plot
# * island barh plot
# * sex barh plot

# %%
df.groupby(["species", "island"]).size().unstack().plot(kind= "bar", figsize= (10, 6), stacked=False)
plt.xticks(rotation=0)
plt.show()

# %%
df= sns.load_dataset("tips")
df.head(50)
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
df["time"].nunique()
# Out:
# 1

# %% [markdown]
# ## You are interested in creating a stacked bar chart of categorical data grouped by day and time as you wish to easily see what times of the day are busiest at lunchtime or dinner time.

# %%
df.groupby(["day", "time"], observed=False).size().unstack().plot(kind="bar", stacked=True, figsize = (10, 6))
plt.show()

# %%
df= sns.load_dataset("penguins")
df
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
df.value_counts("sex", normalize=True)
# Out:
# sex
# Male      0.504505
# Female    0.495495
# Name: proportion, dtype: float64

# %%
df.value_counts("sex", normalize=True).plot(kind="pie", y="island", title= "Penguin sex pie chart")
plt.show()

# %%
for col in df.select_dtypes(include="object").columns:
    df.value_counts(col, normalize=True).plot(kind="pie", y="", title=f"* {col} pie chart")
    plt.show()
    print("\n\n")

# %%
df1= sns.load_dataset("tips")
df1= df1.head(50)
df1
# Out:
#     total_bill   tip     sex smoker  day    time  size
# 0        16.99  1.01  Female     No  Sun  Dinner     2
# 1        10.34  1.66    Male     No  Sun  Dinner     3
# 2        21.01  3.50    Male     No  Sun  Dinner     3
# 3        23.68  3.31    Male     No  Sun  Dinner     2
# 4        24.59  3.61  Female     No  Sun  Dinner     4
# 5        25.29  4.71    Male     No  Sun  Dinner     4
# 6         8.77  2.00    Male     No  Sun  Dinner     2
# 7        26.88  3.12    Male     No  Sun  Dinner     4
# 8        15.04  1.96    Male     No  Sun  Dinner     2
# 9        14.78  3.23    Male     No  Sun  Dinner     2
# 10       10.27  1.71    Male     No  Sun  Dinner     2
# 11       35.26  5.00  Female     No  Sun  Dinner     4
# 12       15.42  1.57    Male     No  Sun  Dinner     2
# 13       18.43  3.00    Male     No  Sun  Dinner     4
# 14       14.83  3.02  Female     No  Sun  Dinner     2
# 15       21.58  3.92    Male     No  Sun  Dinner     2
# ...

# %%
for col in df1.select_dtypes(include="category").columns:
    df1[col] = df1[col].astype("object")
    df1[col].value_counts(col, normalize=True).plot(kind= "pie", ylabel="", title= f"* {col} pie chart")
    plt.show()
    print("\n\n")

# %% [markdown]
# ### the above section needs extensive practice
