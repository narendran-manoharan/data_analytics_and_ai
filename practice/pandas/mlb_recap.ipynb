# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df= sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
np.random.seed(seed=1401)
df= plt.plot(np.random.rand(50))
df

# %%
np.random.seed(seed=1405)
fig, axes= plt.subplots(nrows= 3, ncols= 2, figsize = (10,6))
axes[2, 1].plot(np.random.rand(3))
axes[0, 0].plot(np.random.rand(12))
plt.show()

# %%
df= pd.read_csv("UK_MacroData.CSV")
df
# Out:
#     Unnamed: 0     Date  GDP (£ m)  CPI  Bank Rate  \
# 0            0  2000 Q1     401242  1.1      5.875
# 1            1  2000 Q2     404196  1.0      6.000
# 2            2  2000 Q3     406795  1.2      6.000
# 3            3  2000 Q4     409411  1.4      6.000
# 4            4  2001 Q1     413054  1.3      5.750
# ..         ...      ...        ...  ...        ...
# 91          91  2022 Q4     568034  9.4      3.250
# 92          92  2023 Q1     569336  9.0      4.125
# 93          93  2023 Q2     569364  7.7      4.750
# 94          94  2023 Q3     568655  6.3      5.250
# 95          95  2023 Q4     566695  4.4      5.250
#
#     Gross Fixed Capital Formation (Investments)
# 0                                       69114.0
# 1                                       73074.0
# 2                                       68011.0
# 3                                       70115.0
# 4                                       70186.0
# ..                                          ...
# ...

# %%
df["Year"] = df["Date"].str[:4]
df["Quarter"]= df["Date"].str[-2:]
df["Date"] = pd.to_datetime(df["Year"] + "-" + df["Quarter"])
df= df.set_index("Date")
df
# Out:
# C:\Users\mshin\AppData\Local\Temp\ipykernel_15020\4241183316.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Year"] + "-" + df["Quarter"])
#             Unnamed: 0  GDP (£ m)  CPI  Bank Rate  \
# Date
# 2000-01-01           0     401242  1.1      5.875
# 2000-04-01           1     404196  1.0      6.000
# 2000-07-01           2     406795  1.2      6.000
# 2000-10-01           3     409411  1.4      6.000
# 2001-01-01           4     413054  1.3      5.750
# ...                ...        ...  ...        ...
# 2022-10-01          91     568034  9.4      3.250
# 2023-01-01          92     569336  9.0      4.125
# 2023-04-01          93     569364  7.7      4.750
# 2023-07-01          94     568655  6.3      5.250
# 2023-10-01          95     566695  4.4      5.250
#
# ...

# %% [markdown]
# ### plt.plot() is a basic command and gives a very simple line graph.
#  - remember to call the df and then the column.

# %%
plt.plot(df[["Gross Fixed Capital Formation (Investments)", "GDP (£ m)"]])

# %%
df = pd.read_csv("Online_Retail.csv")
df = df.sample(n=50, random_state=9)
df.head(3)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 442374    574672     22645  CERAMIC HEART FAIRY CAKE MONEY BANK         1
# 527147    580695     21810     CHRISTMAS HANGING STAR WITH BELL         2
# 408638    571987     22636   CHILDS BREAKFAST SET CIRCUS PARADE         4
#
#                 InvoiceDate  UnitPrice  CustomerID         Country
# 442374  2011-11-06 12:25:00       1.45       13532  United Kingdom
# 527147  2011-12-05 16:03:00       0.39       13230  United Kingdom
# 408638  2011-10-20 10:47:00       8.50       17007  United Kingdom

# %% [markdown]
# ### In Histogram, you pass through data, X, and bins.

# %%
plt.hist(data= df, x="Quantity", bins=30)
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(10,6))
axes[0,1].hist(data=df, x= "Quantity")
axes[1,1].hist(data=df["UnitPrice"], x= "Quantity")
plt.show()

# %%
for col in ["Quantity","UnitPrice"]:
    plt.hist(data=df, x=col, label=col)
plt.legend()
plt.show()

# %% [markdown]
# ### In Boxplot, you pass through data, and X.

# %%
plt.boxplot(data= df, x="Quantity")
plt.show()

# %%
list_of_data= []
varaibles_boxplot= ["Quantity", "UnitPrice"]
for col in varaibles_boxplot:
    list_of_data.append(df[col])

plt.boxplot(x=list_of_data)
plt.xticks(np.arange(1,len(varaibles_boxplot)+1), varaibles_boxplot)
plt.show()

# %%
plt.boxplot(data=df, x="UnitPrice")
plt.show()

# %%
plt.boxplot(data=df, x=df[["UnitPrice", "Quantity"]])
plt.show()

# %% [markdown]
# In Scatter plot, there's data, X, Y, c for color, and s for size

# %%
x, y= "Quantity", "UnitPrice"
plt.scatter(data= df, x=x, y=y,c=y, s= df["UnitPrice"] * 3)
plt.ylabel(y)
plt.xlabel(x)
plt.show()

# %%
df= pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
categorical_count= df.value_counts("region")
categorical_count
# Out:
# region
# southeast    364
# northwest    325
# southwest    325
# northeast    324
# Name: count, dtype: int64

# %%
plt.bar(x=categorical_count.index, height= categorical_count)
plt.show()

# %%
plt.barh(y= categorical_count.index, width= categorical_count)
plt.show()

# %%
categorical_count= df.value_counts("region", normalize=True)
plt.pie(x= categorical_count, labels=categorical_count.index)
plt.title("Regional data")
plt.show()

# %%
y= plt.figure()
axes= plt.axes(projection="3d")

# %%
new_plot= plt.figure()
ax = plt.axes(projection="3d")
z= np.linspace(0, 5, 500)
x= z * np.sin(20 * z)
y= z * np.cos(20 * z)
ax.plot3D(x, y, z)
plt.show()

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
fig = plt.figure(figsize=(10, 6))
ax = plt.axes(projection= "3d")

x = df["age"]
y= df["children"]
z= df["bmi"]


ax.scatter(x, y, z)
plt.show()

# %%
df = sns.load_dataset("diamonds")
df
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.axes(projection="3d")

x= df['carat']
y= df['depth']
z= df['price']

ax.plot3D(x, y, z)
plt.show()

# %%
image_url = "https://de.wiktionary.org/wiki/butterfly#/media/Datei:Danaus_plexippus_MHNT_dos.jpg"
im_task = plt.imread(image_url, format="png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 2
#       1 image_url = "https://de.wiktionary.org/wiki/butterfly#/media/Datei:Danaus_plexippus_MHNT_dos.jpg"
# ----> 2 im_task = plt.imread(image_url, format="png")
#
# File c:\Users\mshin\vs-code-projects\demo\.venv\Lib\site-packages\matplotlib\pyplot.py:2615, in imread(fname, format)
#    2611 @_copy_docstring_and_deprecators(matplotlib.image.imread)
#    2612 def imread(
#    2613         fname: str | pathlib.Path | BinaryIO, format: str | None = None
#    2614 ) -> np.ndarray:
# -> 2615     return matplotlib.image.imread(fname, format)
#
# File c:\Users\mshin\vs-code-projects\demo\.venv\Lib\site-packages\matplotlib\image.py:1515, in imread(fname, format)
#    1511 img_open = (
#    1512     PIL.PngImagePlugin.PngImageFile if ext == 'png' else PIL.Image.open)
# ...
