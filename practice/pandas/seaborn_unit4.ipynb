# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.jointplot(data=df, x="total_bill", y="tip", hue="smoker")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 sns.jointplot(data=df, x="total_bill", y="tip", hue="smoker", kind="hex")
#       2 plt.show()
#
# File c:\Users\mshin\vs-code-projects\demo\.venv\Lib\site-packages\seaborn\axisgrid.py:2228, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2226 if hue is not None and kind in ["hex", "reg", "resid"]:
#    2227     msg = f"Use of `hue` with `kind='{kind}'` is not currently supported."
# -> 2228     raise ValueError(msg)
#    2230 # Make a colormap based off the plot color
#    2231 # (Currently used only for kind="hex")
#    2232 if color is None:
#
# ValueError: Use of `hue` with `kind='hex'` is not currently supported.

# %%
sns.jointplot(data=df, x="total_bill", y="tip", kind="hex")
plt.show()

# %% [markdown]
# ### Lmplot - linear model plots
#  - when there is a linear relationship between two variables

# %%
df=pd.read_csv("insurance.csv")
df=df.sample(n=30, random_state=1)
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 559    19    male  35.530         0     no  northwest   1646.42970
# 1087   57    male  31.540         0     no  northwest  11353.22760
# 1020   51    male  37.000         0     no  southwest   8798.59300
# 460    49  female  36.630         3     no  southeast  10381.47870
# 802    21    male  22.300         1     no  southwest   2103.08000
# 298    31    male  34.390         3    yes  northwest  38746.35510
# 481    49    male  37.510         2     no  southeast   9304.70190
# 616    56  female  28.595         0     no  northeast  11658.11505
# 763    27    male  26.030         0     no  northeast   3070.80870
# 750    37  female  26.400         0    yes  southeast  19539.24300
# 48     60  female  24.530         0     no  southeast  12629.89670
# 547    54  female  46.700         2     no  southwest  11538.42100
# 1143   39    male  32.340         2     no  southeast   6338.07560
# ...

# %%
sns.lmplot(data=df, x="bmi", y="charges")
plt.show()

# %%
sns.lmplot(data=df, x="age", y="charges")
plt.show()

# %%
sns.lmplot(data= df, x="bmi", y="charges", col="smoker", ci=None)
plt.show()

# %%
sns.lmplot(data= df, x="bmi", y="charges", col="smoker", row="region", ci=None)
plt.show()

# %%
sns.lmplot(data=df, x="bmi", y="charges", hue="smoker", ci=None)
plt.show()

# %%
df = pd.read_csv("UK_MacroData.CSV")
df
# Out:
#     Unnamed: 0     Date  GDP (£ m)  CPI  Bank Rate  \
# 0            0  2000 Q1     401242  1.1      5.875
# 1            1  2000 Q2     404196  1.0      6.000
# 2            2  2000 Q3     406795  1.2      6.000
# 3            3  2000 Q4     409411  1.4      6.000
# 4            4  2001 Q1     413054  1.3      5.750
# ..         ...      ...        ...  ...        ...
# 91          91  2022 Q4     568034  9.4      3.250
# 92          92  2023 Q1     569336  9.0      4.125
# 93          93  2023 Q2     569364  7.7      4.750
# 94          94  2023 Q3     568655  6.3      5.250
# 95          95  2023 Q4     566695  4.4      5.250
#
#     Gross Fixed Capital Formation (Investments)
# 0                                       69114.0
# 1                                       73074.0
# 2                                       68011.0
# 3                                       70115.0
# 4                                       70186.0
# ..                                          ...
# ...

# %%
sns.lmplot(data=df, x="Gross Fixed Capital Formation (Investments)", y="CPI")
plt.show()

# %%
sns.lmplot(data=df, x="Gross Fixed Capital Formation (Investments)", y="CPI", order=3)
plt.show()

# %% [markdown]
# ### Scatter takes all parameters like hue, size, and so on.
# - one unique thing about sns.scatter is that it allows numerical values to be added as hues.

# %%
df=pd.read_csv("insurance.csv")
df=df.sample(n=30, random_state=1)
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 559    19    male  35.530         0     no  northwest   1646.42970
# 1087   57    male  31.540         0     no  northwest  11353.22760
# 1020   51    male  37.000         0     no  southwest   8798.59300
# 460    49  female  36.630         3     no  southeast  10381.47870
# 802    21    male  22.300         1     no  southwest   2103.08000
# 298    31    male  34.390         3    yes  northwest  38746.35510
# 481    49    male  37.510         2     no  southeast   9304.70190
# 616    56  female  28.595         0     no  northeast  11658.11505
# 763    27    male  26.030         0     no  northeast   3070.80870
# 750    37  female  26.400         0    yes  southeast  19539.24300
# 48     60  female  24.530         0     no  southeast  12629.89670
# 547    54  female  46.700         2     no  southwest  11538.42100
# 1143   39    male  32.340         2     no  southeast   6338.07560
# ...

# %%
fig, axes= plt.subplots(nrows=2, ncols=2, figsize=(12,8))
sns.scatterplot(data=df, x="age", y="charges", ax=axes[0,1])
plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=2, figsize=(12,8))
sns.scatterplot(data=df, x="age", y="charges", ax=axes[0,1])
sns.scatterplot(data=df, x="age", y="region", ax=axes[1,0])
plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=2, figsize=(12,8))
sns.scatterplot(data=df, x="age", y="charges", hue="bmi", ax=axes[0,0])
plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=2, figsize=(12,8))
sns.scatterplot(data=df, x="age", y="charges", ax=axes[0,1], size="bmi")
plt.show()

# %%
fig, axes= plt.subplots(nrows=2, ncols=2, figsize=(12,8))
sns.scatterplot(data=df, x="age", y="charges", ax=axes[0,1], size="bmi", sizes=(40, 200))
plt.show()

# %% [markdown]
# ## Pairplot

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 559    19    male  35.530         0     no  northwest   1646.42970
# 1087   57    male  31.540         0     no  northwest  11353.22760
# 1020   51    male  37.000         0     no  southwest   8798.59300
# 460    49  female  36.630         3     no  southeast  10381.47870
# 802    21    male  22.300         1     no  southwest   2103.08000
# 298    31    male  34.390         3    yes  northwest  38746.35510
# 481    49    male  37.510         2     no  southeast   9304.70190
# 616    56  female  28.595         0     no  northeast  11658.11505
# 763    27    male  26.030         0     no  northeast   3070.80870
# 750    37  female  26.400         0    yes  southeast  19539.24300
# 48     60  female  24.530         0     no  southeast  12629.89670
# 547    54  female  46.700         2     no  southwest  11538.42100
# 1143   39    male  32.340         2     no  southeast   6338.07560
# ...

# %%
sns.pairplot(data=df, plot_kws={"alpha":0.8})
plt.show()

# %%
fig = sns.pairplot(data=df, plot_kws={"alpha":0.8})
for i, j in zip(*np.triu_indices_from(fig.axes, 1)):
    fig.axes[i, j].set_visible(False)
plt.show()
